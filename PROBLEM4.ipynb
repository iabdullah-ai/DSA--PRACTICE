# %% [markdown]
# # Given a string s, partition s such that every substring of the partition is a palindrome. Return all #possible palindrome partitioning of s.   A palindrome string is a string that reads the same backward as forward.ExamplesExample 1:Input: s = "aab"   Output: [["a","a","b"],["aa","b"]]   # Example 2:Input: s = "a"   Output: [["a"]]

# %%
def palin(s:str) -> list:
    palindrome = []
    def counter(left:int,right:int):
        while left>=0 and right<len(s) and s[left]==s[right]:
            palindrome.append(s[left:right+1])
            left-=1
            right+=1
    for i in range(len(s)):
            counter(i,i)
            counter(i,i+1)
    return palindrome
print(palin("abbacc"))
# Out:
# ['a', 'b', 'bb', 'abba', 'b', 'a', 'c', 'cc', 'c']
